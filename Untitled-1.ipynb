# %%
# 1. Create the virtual environment (once)
python3 -m venv venv

# 2. Activate it
source venv/bin/activate        # Mac/Linux
venv\Scripts\activate           # Windows

# 3. Now install and run as normal
pip install -r requirements.txt
streamlit run app.py


deactivate
